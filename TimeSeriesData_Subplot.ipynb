# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/MyDrive/dataset/AirPassengers.csv')
data['Month'] = pd.to_datetime(data['Month'])
data.set_index('Month', inplace=True)


plt.figure(figsize=(7, 5))
plt.plot(data)
plt.title('Air Passengers Time Series')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
Data={
    "Date": pd.to_datetime(["2022-01-01","2022-02-01","2022-03-01","2022-04-01","2022-05-01","2022-06-01","2022-07-01","2022-08-01","2022-09-01","2022-10-01","2022-11-01","2022-12-01","2023-01-01","2023-02-01","2023-03-01"]),
    "Value": [10,15,22,28,35,42,48,55,60,68,75,82,90,98,105]
}

# %%
df=pd.DataFrame(Data)
df.set_index("Date",inplace=True)
plt.figure(figsize=(10,6))
plt.plot(df.index,df["Value"],marker="o")
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("Time Series with trend")
plt.grid(True)
plt.show()

# %%
Data={
    "Date": pd.to_datetime(["2022-01-01","2022-02-01","2022-03-01","2022-04-01","2022-05-01","2022-06-01","2022-07-01","2022-08-01","2022-09-01","2022-10-01","2022-11-01","2022-12-01","2023-01-01","2023-02-01","2023-03-01"]),
    "Value": [10,15,12,16,18,20,26,28,30,32,36,24,22,36,38]
}

# %%
df=pd.DataFrame(Data)
df.set_index("Date",inplace=True)
plt.figure(figsize=(10,6))
plt.plot(df.index,df["Value"])
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("Time Series with seasonality")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Subplots

# %%
plt.subplot(1,3,1)
plt.plot(df.index,df["Value"],marker="o")

plt.subplot(1,3,2)
plt.plot(data)

plt.subplot(1,3,3)
plt.plot(df.index,df["Value"])
